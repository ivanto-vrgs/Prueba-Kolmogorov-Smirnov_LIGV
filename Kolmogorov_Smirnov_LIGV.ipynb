# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanto-vrgs/Prueba-Kolmogorov-Smirnov_LIGV/blob/main/Kolmogorov_Smirnov_LIGV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

#conjunto de 100 datos
data = [
    0.78961, 0.05230, 0.10699, 0.55877, 0.14151,
    0.76086, 0.12079, 0.27738, 0.65726, 0.79269,
    0.80548, 0.82654, 0.29453, 0.20852, 0.42989,
    0.58518, 0.98611, 0.34488, 0.34358, 0.11537,
    0.89898, 0.57880, 0.67621, 0.05010, 0.00121,
    0.28269, 0.73059, 0.70119, 0.18284, 0.49962,
    0.38618, 0.76910, 0.68334, 0.55170, 0.10850,
    0.79882, 0.45679, 0.21631, 0.87616, 0.55743,
    0.58962, 0.33216, 0.03185, 0.61168, 0.09264,
    0.69623, 0.17028, 0.05475, 0.91512, 0.76262,
    0.29931, 0.30861, 0.83358, 0.51781, 0.03272,
    0.57410, 0.26593, 0.85903, 0.43308, 0.35286,
    0.24000, 0.65559, 0.38507, 0.90829, 0.94187,
    0.93655, 0.88809, 0.81772, 0.36982, 0.19904,
    0.54325, 0.62400, 0.09133, 0.41678, 0.33954,
    0.58244, 0.85853, 0.86752, 0.38729, 0.15506,
    0.23949, 0.53559, 0.33381, 0.49883, 0.75103,
    0.19962, 0.65002, 0.74579, 0.79113, 0.63453,
    0.19147, 0.40644, 0.08128, 0.73435, 0.22724,
    0.22287, 0.07281, 0.64183, 0.44267, 0.72102
]

def prueba_kolmogorov_smirnov(datos, alpha=0.05):
    n = len(datos)

    datos_ordenados = sorted(datos)

    d_plus = []
    d_minus = []

    for i in range(1, n + 1):
        ri = datos_ordenados[i-1]
        d_plus.append((i / n) - ri)
        d_minus.append(ri - ((i - 1) / n))

    max_d_plus = max(d_plus)
    max_d_minus = max(d_minus)


    d_estadistico = max(max_d_plus, max_d_minus)


    valor_critico = 1.36 / np.sqrt(n)

    return {
        "n": n,
        "D+": max_d_plus,
        "D-": max_d_minus,
        "D_estadistico": d_estadistico,
        "Valor_Critico": valor_critico,
        "Resultado": "No se rechaza H0" if d_estadistico < valor_critico else "Se rechaza H0"
    }

#Generar los resultados
resultados = prueba_kolmogorov_smirnov(data)

# Imprimir resultados
print(f"Tamaño de la muestra (n): {resultados['n']}")
print(f"D+ máximo: {resultados['D+']}")
print(f"D- máximo: {resultados['D-']}")
print(f"Estadístico D: {resultados['D_estadistico']}")
print(f"Valor Crítico: {resultados['Valor_Critico']}")
print(f"Decisión: {resultados['Resultado']}")
# Out:
# Tamaño de la muestra (n): 100
# D+ máximo: 0.056420000000000026
# D- máximo: 0.02185
# Estadístico D: 0.056420000000000026
# Valor Crítico: 0.136
# Decisión: No se rechaza H0
